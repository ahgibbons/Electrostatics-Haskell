# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
import matplotlib as mpl
LEGEND_SIZE = 10
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=LEGEND_SIZE, frameon=False)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('figure', dpi=100, figsize=(4.6,3.3))

# %%
print(os.listdir())
# Out:
# ['func.csv', 'estatic.cabal', 'CHANGELOG.md', 'epsilon.csv', 'grady.csv', 'Ey.csv', 'test.csv', 'plots.ipynb', 'CHANGELOG.md\uf03aZone.Identifier', 'charge.csv', 'LICENSE\uf03aZone.Identifier', 'test3.csv', 'Ex.csv', 'phi.csv', 'dist-newstyle', 'estatic.cabal\uf03aZone.Identifier', 'gradx.csv', '.git', '.gitignore', 'app', 'LICENSE', 'test2.csv']

# %%
foo = pd.read_csv("test.csv", header=None)
bar = pd.read_csv("test2.csv", header=None)
foobar = pd.read_csv("test3.csv", header=None)

epsilon = pd.read_csv("epsilon.csv", header=None)
phi = pd.read_csv("phi.csv", header=None)
charge = pd.read_csv("charge.csv", header=None)

ex = pd.read_csv("Ex.csv", header=None)
ey = pd.read_csv("Ey.csv", header=None)

# %%
plt.imshow(phi, origin="lower")
plt.show()
plt.imshow(charge, origin="lower")
plt.show()
plt.imshow(epsilon, origin="lower")
plt.show()
plt.quiver(ex.iloc[1:-1:2,1:-1:2],ey.iloc[1:-1:2,1:-1:2])
plt.show()
